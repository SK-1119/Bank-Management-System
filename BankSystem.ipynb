# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image,ImageTk
import mysql.connector
conn=mysql.connector.connect(host="localhost",port="3306",user="root")
cur=conn.cursor()
try:
    cur.execute("create database bank;")
    cur.execute("use bank;")
except:
    cur.execute("use bank;")
try:
    cur.execute("create table adata(Username varchar(30) unique key,Password varchar(30),Name varchar(30),EmpId int,Address varchar(100));")
    cur.execute("insert into adata values('SK1119','SK@1119','SK',1,'Kaithal');")
    cur.execute("insert into adata values('MK9222','MK@9222','MK',2,'Ellenabad');")
except:
    pass
try:
    cur.execute("create table tempdata(Username varchar(30) primary key,Password varchar(30),Name varchar(30),PhNo varchar(13) unique key,Email varchar(100) unique key,Fname varchar(50),Mname varchar(50),PAN varchar(30) unique key,Aadhar varchar(16) unique key,Address varchar(100),Occupation varchar(50),income varchar(100),Marital varchar(30),Gender varchar(20),DOB date);")
except:
    pass
try:
    cur.execute("create table nominee(Nname varchar(50),relation varchar(30),ndob date,naddress varchar(100),Pincode int);")
except:
    pass
try:
    cur.execute("create table cdata(Username varchar(30) primary key,Password varchar(30),AccountNo varchar(25) unique key,Name varchar(30),PhNo varchar(13),Email varchar(100),Fname varchar(50),Mname varchar(50),PAN varchar(30),Aadhar varchar(16),Address varchar(100),Occupation varchar(50),income varchar(100),Marital varchar(30),Gender varchar(20),DOB date,Nname varchar(50),relation varchar(30),ndob date,naddress varchar(100),Pincode int);")
except:
    pass
try:
    cur.execute("create trigger t after insert on cdata for each row delete from tempdata where new.username = tempdata.username;")
except:
    pass
class bank:
    def home(self):
        self.fh=Tk()
        self.w=self.fh.winfo_screenwidth()
        self.h=self.fh.winfo_screenheight()
        self.fh.geometry(f"{self.w}x{self.h}")
        self.fh.configure(bg="black")
        self.fh.title("KnK Bank")
        l=Label(self.fh,text="Welcome To KnK Bank!",bg="black",fg="white",font=("MV Boli",34))
        l.place(relx=0.335,rely=0.25)
        l1=Label(self.fh,text="Username:",bg="black",fg="white",font=("Comic Sans",20))
        l1.place(relx=0.34,rely=0.4)
        l2=Label(self.fh,text="Password:",bg="black",fg="white",font=("Comic Sans",20))
        l2.place(relx=0.34,rely=0.47)
        self.cu=Entry(self.fh,bg="white",fg="Black",font=("MV Boli",20))
        self.cu.place(relx=0.45,rely=0.40)
        self.cp=Entry(self.fh,bg="white",fg="Black",font=("MV Boli",20))
        self.cp.place(relx=0.45,rely=0.47)
        b=Button(self.fh,text="LOGIN",bg="turquoise",fg="black",font=("MV Boli",22),command=loginl)
        b.place(relx=0.477,rely=0.53)
        l3=Label(self.fh,text="Don't Have An Account? ",bg="black",fg="#F9F270",font=("Comic Sans",13))
        l3.place(relx=0.41,rely=0.628)
        b1=Button(self.fh,text="Sign Up",bg="black",fg="#F3CD12",font=("MV Boli",12),command=sign)
        b1.place(relx=0.54,rely=0.618)
        b2=Button(self.fh,text="Admin",bg="black",fg="Turquoise",font=("MV Boli",14),command=x)
        b2.place(relx=0.93,rely=0.035)
        self.fh.mainloop()
    def user(self):
        self.sh.destroy()
        self.use=Tk()
        self.use.configure(bg="black")
        self.use.geometry("600x400")
        self.use.title("Credentials")
        l=Label(self.use,text="Username:",bg="black",fg="white",font=("MV Boli",22))
        l.place(relx=0.14,rely=0.2)
        self.e90=Entry(self.use,bg="white",fg="black",font=("Comic Sans",17))
        self.e90.place(relx=0.42,rely=0.21)
        l1=Label(self.use,text="Password:",bg="black",fg="white",font=("MV Boli",22))
        l1.place(relx=0.14,rely=0.36)
        self.e91=Entry(self.use,bg="white",fg="black",font=("Comic Sans",17))
        self.e91.place(relx=0.42,rely=0.361)
        b=Button(self.use,text="OK",bg="black",fg="turquoise",font=("MV Boli",22),command=ok)
        b.place(relx=0.495,rely=0.55)
        self.use.mainloop()
    def login(self):
        self.lh=Tk()
        self.lh.geometry(f"{self.w}x{self.h}")
        self.lh.configure(bg="black")
        self.lh.title("KnK Bank")
        l=Label(self.lh,text="Welcome To KnK Bank's ATM!",bg="black",fg="white",font=("MV Boli",34))
        l.place(relx=0.29,rely=0.25)
        b=Button(self.lh,text="Balance Enquiry",bg="black",fg="turquoise",font=("Comic Sans",20))
        b.place(relx=0.05,rely=0.45,relwidth=0.25)
        b1=Button(self.lh,text="Deposit",bg="black",fg="turquoise",font=("Comic Sans",20))
        b1.place(relx=0.05,rely=0.55,relwidth=0.25)
        b2=Button(self.lh,text="Change Mobile Number",bg="black",fg="turquoise",font=("Comic Sans",20))
        b2.place(relx=0.05,rely=0.65,relwidth=0.25)
        b3=Button(self.lh,text="Mini Statement",bg="black",fg="turquoise",font=("Comic Sans",20))
        b3.place(relx=0.715,rely=0.45,relwidth=0.25)
        b4=Button(self.lh,text="Cash Withdrawal",bg="black",fg="turquoise",font=("Comic Sans",20))
        b4.place(relx=0.715,rely=0.55,relwidth=0.25)
        b5=Button(self.lh,text="Change PIN",bg="black",fg="turquoise",font=("Comic Sans",20))
        b5.place(relx=0.715,rely=0.65,relwidth=0.25)
        LB=Button(self.lh,text="LOGOUT",bg="black",fg="turquoise",font=("Comic Sans",20),command=y)
        LB.place(relx=0.485,rely=0.8)
        self.lh.mainloop()
    def admin(self):
        self.ah=Tk()
        self.ah.geometry(f"{self.w}x{self.h}")
        self.ah.title('Admin')
        self.ah.configure(bg='black')
        l1=Label(self.ah,text="Welcome to KnK's Admin Page",fg='white',bg='black',font=('MV Boli',34))
        l1.place(relx=0.327,rely=0.2)
        l2=Button(self.ah,text="Pending Request",fg='turquoise',bg='black',font=("Comic Sans",20))
        l2.place(relx=0.0535,rely=0.4,relwidth=0.25)
        l3=Button(self.ah,text="Approve Deposit's",fg='turquoise',bg='black',font=("Comic Sans",20))
        l3.place(relx=0.0532,rely=0.6,relwidth=0.25)
        l4=Button(self.ah,text="Loan Approvals",fg='turquoise',bg='black',font=("Comic Sans",20))
        l4.place(relx=0.682,rely=0.4,relwidth=0.25)
        l5=Button(self.ah,text="Passbook Updation",fg='turquoise',bg='black',font=("Comic Sans",20))
        l5.place(relx=0.682,rely=0.6,relwidth=0.25)
        LB=Button(self.ah,text="LOGOUT",bg="black",fg="turquoise",font=("Comic Sans",20),command=lo)
        LB.place(relx=0.355,rely=0.8)
        HB=Button(self.ah,text="HOME",bg="black",fg="turquoise",font=("Comic Sans",20),command=ol)
        HB.place(relx=0.605,rely=0.8)
        self.ah.mainloop()
    def adminl(self):
        self.al=Tk()
        self.al.title("Admin Login")
        self.al.geometry(f"{self.w}x{self.h}")
        self.al.configure(bg="black")
        l=Label(self.al,text="Admin Login Into KnK Bank",bg="black",fg="white",font=("MV Boli",34))
        l.place(relx=0.335,rely=0.25)
        l1=Label(self.al,text="Username:",bg="black",fg="white",font=("Comic Sans",20))
        l1.place(relx=0.34,rely=0.4)
        l2=Label(self.al,text="Password:",bg="black",fg="white",font=("Comic Sans",20))
        l2.place(relx=0.34,rely=0.47)
        self.au=Entry(self.al,bg="white",fg="white",font=("MV Boli",20))
        self.au.place(relx=0.45,rely=0.40)
        self.ap=Entry(self.al,bg="white",fg="white",font=("MV Boli",20))
        self.ap.place(relx=0.45,rely=0.47)
        b=Button(self.al,text="LOGIN",bg="turquoise",fg="black",font=("MV Boli",22),command=adminf)
        b.place(relx=0.477,rely=0.53)
        b1=Button(self.al,text="Back",fg="turquoise",bg="black",font=("Comic Sans",10),command=a)
        b1.place(relx=0.02,rely=0.02)
        self.al.mainloop()
    def signup(self):
        self.sh=Tk()
        self.sh.geometry(f"{self.w}x{self.h}")
        self.sh.configure(bg="black")
        self.sh.title("Get Started Now")
#         s=Scrollbar(self.sh)
#         s.pack(side=RIGHT,fill=Y)
        
        #LABELS
        z=Label(self.sh,text="Register Yourself",bg="black",fg="turquoise",font=("MV Boli",25))
        z.place(relx=0.2,rely=0.085)
        l=Label(self.sh,text="Full Name:",bg="black",fg="white",font=("MV Boli",20))
        l.place(relx=0.3,rely=0.15)
        self.e1=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e1.place(relx=0.45,rely=0.15)
        l1=Label(self.sh,text="Mobile Number:",bg="black",fg="white",font=("MV Boli",20))
        l1.place(relx=0.3,rely=0.20)
        self.e2=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e2.place(relx=0.45,rely=0.20)
        l2=Label(self.sh,text="Email Address:",bg="black",fg="white",font=("MV Boli",20))
        l2.place(relx=0.3,rely=0.25)
        self.e3=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e3.place(relx=0.45,rely=0.25)
        l3=Label(self.sh,text="Father's Name:",bg="black",fg="white",font=("MV Boli",20))
        l3.place(relx=0.3,rely=0.30)
        self.e4=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e4.place(relx=0.45,rely=0.30)
        l4=Label(self.sh,text="Mother's Name:",bg="black",fg="white",font=("MV Boli",20))
        l4.place(relx=0.3,rely=0.35)
        self.e5=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e5.place(relx=0.45,rely=0.35)
        l5=Label(self.sh,text="PAN Number:",bg="black",fg="white",font=("MV Boli",20))
        l5.place(relx=0.3,rely=0.40)
        self.e6=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e6.place(relx=0.45,rely=0.40)
        l6=Label(self.sh,text="Aadhar Number:",bg="black",fg="white",font=("MV Boli",20))
        l6.place(relx=0.3,rely=0.45)
        self.e7=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e7.place(relx=0.45,rely=0.45)
        l7=Label(self.sh,text="Address:",bg="black",fg="white",font=("MV Boli",20))
        l7.place(relx=0.3,rely=0.50)
        self.e8=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e8.place(relx=0.45,rely=0.50)
        l8=Label(self.sh,text="Occupation:",bg="black",fg="white",font=("MV Boli",20))
        l8.place(relx=0.3,rely=0.55)
        self.op=['Student','Doctor','Engineer','Teacher','Charted Accounted','Entreprenuer','Labour','others']
        self.kkks=StringVar()
        self.kkks.set("Select your Occupation")
#         print(self.kkks.get())
        self.m=OptionMenu(self.sh, self.kkks, *self.op)
        self.m.configure(bg="black",fg="turquoise",font=("Comic Sans",17))
        self.m.place(relx=0.45,rely=0.55)
        l9=Label(self.sh,text="Annual Income:",bg="black",fg="white",font=("MV Boli",20))
        l9.place(relx=0.3,rely=0.60)
        self.jp=['Less than 2.5 Lakhs','2.5 Lakhs-4 Lakhs','4 Lakhs-5.5 Lakhs','5.5 Lakhs-7 Lakhs','7 Labkhs Above']
        self.j=StringVar()
        self.j.set("Choose Annual Income")
        self.r=OptionMenu(self.sh,self.j,*self.jp)
        self.r.configure(bg="black",fg="turquoise",font=("Comic Sans",17))
        self.r.place(relx=0.45,rely=0.60)
        l10=Label(self.sh,text="Marital Status:",bg="black",fg="white",font=("MV Boli",20))
        l10.place(relx=0.3,rely=0.65)
        self.var1=StringVar()
        self.var2=StringVar()
        r1=Radiobutton(self.sh,text="Single",variable=self.var1,value="Single",bg="black",fg="turquoise",font=("Comic Sans",17))
        r1.place(relx=0.45,rely=0.65)
        r2=Radiobutton(self.sh,text="Married",variable=self.var1,value="Married",bg="black",fg="turquoise",font=("Comic Sans",17))
        r2.place(relx=0.55,rely=0.65)
        r3=Radiobutton(self.sh,text="Divorcee",variable=self.var1,value="Divorcee",bg="black",fg="turquoise",font=("Comic Sans",17))
        r3.place(relx=0.65,rely=0.65)
        r4=Radiobutton(self.sh,text="Widowed",variable=self.var1,value="Widowed",bg="black",fg="turquoise",font=("Comic Sans",17))
        r4.place(relx=0.75,rely=0.65)
        l11=Label(self.sh,text="Gender:",bg="black",fg="white",font=("MV Boli",20))
        l11.place(relx=0.3,rely=0.70)
        r3=Radiobutton(self.sh,text="Male",variable=self.var2,value="Male",bg="black",fg="turquoise",font=("Comic Sans",17))
        r3.place(relx=0.45,rely=0.70)
        r4=Radiobutton(self.sh,text="Female",variable=self.var2,value="Female",bg="black",fg="turquoise",font=("Comic Sans",17))
        r4.place(relx=0.55,rely=0.70)
        r5=Radiobutton(self.sh,text="Others",variable=self.var2,value="Others",bg="black",fg="turquoise",font=("Comic Sans",17))
        r5.place(relx=0.65,rely=0.70)
        l12=Label(self.sh,text="Date of Birth:",bg="black",fg="white",font=("MV Boli",20))
        l12.place(relx=0.3,rely=0.75)
        self.e9=Entry(self.sh,fg='black',bg='white',font=("Comic Sans",17))
        self.e9.place(relx=0.45,rely=0.75)
        self.e9.insert(0,"YYYY-MM-DD")
        self.e9.bind("<FocusIn>", temp_text)
        b1=Button(self.sh,text="Next",fg="turquoise",bg="black",font=("Comic Sans",20),command=nex)
        b1.place(relx=0.45,rely=0.85)
        b2=Button(self.sh,text="Back",fg="turquoise",bg="black",font=("Comic Sans",10),command=g)
        b2.place(relx=0.02,rely=0.02)
        self.sh.mainloop()
       
    def signup2(self):
        self.kh=Tk()
        self.kh.geometry(f"{self.w}x{self.h}")
        self.kh.configure(bg="black")
        self.kh.title("Get Started Now")
        l13=Label(self.kh,text="Nominee's Name:",bg="black",fg="white",font=("MV Boli",20))
        l13.place(relx=0.23,rely=0.15)
        self.e10=Entry(self.kh,fg='black',bg='white',font=("Comic Sans",17))
        self.e10.place(relx=0.57,rely=0.15)
        l14=Label(self.kh,text="Relationship with Account Holder:",bg="black",fg="white",font=("MV Boli",20))
        l14.place(relx=0.23,rely=0.20)
        self.e11=Entry(self.kh,fg='black',bg='white',font=("Comic Sans",17))
        self.e11.place(relx=0.57,rely=0.20)
        l15=Label(self.kh,text="Nominee's Date of Birth:",bg="black",fg="white",font=("MV Boli",20))
        l15.place(relx=0.23,rely=0.25)
        self.e12=Entry(self.kh,fg='black',bg='white',font=("Comic Sans",17))
        self.e12.place(relx=0.57,rely=0.25)
        self.e12.insert(0,"YYYY-MM-DD")
        self.e12.bind("<FocusIn>",temp)
        l16=Label(self.kh,text="Nominee's Address:",bg="black",fg="white",font=("MV Boli",20))
        l16.place(relx=0.23,rely=0.30)
        self.e13=Entry(self.kh,fg='black',bg='white',font=("Comic Sans",17))
        self.e13.place(relx=0.57,rely=0.30)
        l17=Label(self.kh,text="Pincode:",bg="black",fg="white",font=("MV Boli",20))
        l17.place(relx=0.23,rely=0.35)
        self.e14=Entry(self.kh,fg='black',bg='white',font=("Comic Sans",17))
        self.e14.place(relx=0.57,rely=0.35)
        
        #Term n Conditions
        self.v1=IntVar()
        self.v2=IntVar()
        self.v3=IntVar()
        self.v4=IntVar()
        l18=Label(self.kh,text="Term And Conditions",bg="black",fg="Turquoise",font=("MV Boli",30))
        l18.place(relx=0.02,rely=0.42)
        c1=Checkbutton(self.kh,text="I am not Politically Exposed Person",onvalue=1,offvalue=0,variable=self.v1,fg='white',bg='black',font=('georgia',15))
        c1.place(relx=0.05,rely=0.53)
        c2=Checkbutton(self.kh,text="I am an Indian Citizen and a tax resident of India and of no other country",onvalue=1,offvalue=0,variable=self.v2,fg='white',bg='black',font=('georgia',15))
        c2.place(relx=0.05,rely=0.56)
        c3=Checkbutton(self.kh,text="I Confirm the following:",onvalue=1,offvalue=0,variable=self.v3,fg='white',bg='black',font=('georgia',15))
        c3.place(relx=0.05,rely=0.59)
        l19=Label(self.kh,text="1. The address mentioned of my Aadhar card is my permanent address.",bg="black",fg="white",font=("georgia",15))
        l19.place(relx=0.1,rely=0.62)
        l20=Label(self.kh,text="2. I have addiontionally given the above address as my current residential address or local address.",bg="black",fg="white",font=("georgia",15))
        l20.place(relx=0.1,rely=0.65)
        l21=Label(self.kh,text="3. I have provided my local address to open this account.\n",bg="black",fg="white",font=("georgia",15))
        l21.place(relx=0.1,rely=0.68)
        l22=Label(self.kh,text="4. I would like to recieve all account correspondence on my local address.",bg="black",fg="white",font=("georgia",15))
        l22.place(relx=0.1,rely=0.71)
        l23=Label(self.kh,text="I agree and hereby authorize KnK to fetch my personal details from UIDAI.",bg="black",fg="white",font=("georgia",15))
        l23.place(relx=0.05,rely=0.74)
        l24=Label(self.kh,text="I declare that no other account has been opened or will be opened using my Aadhar details as a part of my e-KYC process.",bg="black",fg="white",font=("georgia",15))
        l24.place(relx=0.05,rely=0.77)
        l25=Label(self.kh,text="Disputes,if any,related to KnK Bank shall be subject to the exclusive jurisdiction of the Punjab and Haryana High Court,Chandigarh Only",bg="black",fg="white",font=("georgia",15))
        l25.place(relx=0.05,rely=0.80)
        c4=Checkbutton(self.kh,text="I have read and accept all the Terms and Conditions",onvalue=1,offvalue=0,variable=self.v4,fg='white',bg='black',font=('georgia',15))
        c4.place(relx=0.3,rely=0.83)
        b=Button(self.kh,text="SUBMIT",bg="turquoise",fg="black",font=("MV Boli",17),command=sub)
        b.place(relx=0.486,rely=0.89)
        b1=Button(self.kh,text="Back",fg="turquoise",bg="black",font=("Comic Sans",10),command=ga)
        b1.place(relx=0.025,rely=0.02)
        b2=Button(self.kh,text="Home",fg="turquoise",bg="black",font=("Comic Sans",10),command=gb)
        b2.place(relx=0.065,rely=0.02)
        self.kh.mainloop()
def sub():
    NN=o.e10.get()
    NR=o.e11.get()
    NDOB=o.e12.get()
    NAdd=o.e13.get()
    NPin=o.e14.get()
    a1=o.v1.get()
    a2=o.v2.get()
    a3=o.v3.get()
    a4=o.v4.get()
    if NN is not None and NR is not None and NDOB is not None and NDOB !="YYYY-MM-DD" and NAdd is not None and NPin is not None:
        if a1==1 and a2==1 and a3==1 and a4==1:
            cur.execute(f"insert into nominee values('{NN}','{NR}','{NDOB}','{NAdd}','{NPin}');")
            messagebox.showinfo("Submitted","Your Details Are submitted Please wait for the Approval")
            o.kh.destroy()
            o.home()
        else:
            messagebox.showwarning("Terms N Conditions","Please accept All Terms n Conditions")
    else:
        messagebox.showwarning("Missing Details","Please Fill All Details")
def ok():
    o.U=o.e90.get()
    o.P=o.e91.get()
    if o.U !="" and o.P !="":
        o.use.destroy()
    else:
        messagebox.showwarning("Missing Details","Please Fill all Fields")
def temp_text(e):
    o.e9.delete(0,END)
def temp(e):
    o.e12.delete(0,END)
def sign():
    o.fh.destroy()
    o.signup()
def g():
    o.sh.destroy()
    o.home()
def gb():
    o.kh.destroy()
    o.home()
def ga():
    o.kh.destroy()
    o.signup()
def nex():
    N=o.e1.get()
    PN=o.e2.get()
    Em=o.e3.get()
    FN=o.e4.get()
    MN=o.e5.get()
    PAN=o.e6.get()
    Aad=o.e7.get()
    Add=o.e8.get()
    Occ=o.kkks.get()
    Inc=o.j.get()
    MS=o.var1.get()
    G=o.var2.get()
    DOB=o.e9.get()
#     if MS==1:
#         MS="Single"
#     elif MS==2:
#         MS="Married"
#     elif MS==3:
#         MS="Divorcee"
#     elif MS==4:
#         MS="Widowed"
#     if G==1:
#         G="Male"
#     elif G==2:
#         G="Female"
#     elif G==3:
#         G="Others"
    if N is not None and PN is not None and Em is not None and FN is not None and MN is not None and PAN is not None and Aad is not None and Add is not None and Occ !="Select Your Occupation" and Inc !="Choose Annual Income" and MS !=0 and G !=0 and DOB is not None and DOB !="YYYY-MM-DD":
        #check pan etc.
        o.user()
        cur.execute(f"insert into tempdata values('{o.U}','{o.P}','{N}','{PN}','{Em}','{FN}','{MN}','{PAN}','{Aad}','{Add}','{Occ}','{Inc}','{MS}','{G}','{DOB}');")
        o.signup2()
    else:
        messagebox.showwarning("Missing Details","Please Enter all fields")
def y():
    o.lh.destroy()
    o.home()
def x():
    o.fh.destroy()
    o.adminl()
def lo():
    o.ah.destroy()
    o.adminl()
def ol():
    o.ah.destroy()
    o.home()
def loginl():
    o.fh.destroy()
    o.login()
def adminf():
    o.al.destroy()
    o.admin()
def a():
    o.al.destroy()
    o.home()
o=bank()
o.home()
cur.close()
conn.commit()
conn.close()
